# %% [markdown]
# <a href="https://colab.research.google.com/github/prapartha/IBM-Qiskit-v2.X-Quantum-software-developer-certification-sg6-group/blob/main/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
